# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine ('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
df_iter=pd.read_csv('green_tripdata_2019-10.csv.gz', iterator=True, chunksize=100000)

# %%
df=next(df_iter)

# %%
df
# Out:
#        VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0             2  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1             1  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2             1  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3             1  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4             2  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
# ...         ...                  ...                   ...                ...
# 99995         2  2019-10-08 15:45:56   2019-10-08 15:54:45                  N
# 99996         2  2019-10-08 15:43:31   2019-10-08 15:50:11                  N
# 99997         2  2019-10-08 15:57:26   2019-10-08 16:17:41                  N
# 99998         2  2019-10-08 14:58:24   2019-10-08 15:03:40                  N
# 99999         2  2019-10-08 15:10:20   2019-10-08 15:17:44                  N
#
# ...

# %%
df.head(n=0).to_sql(name='taxi_trips_10_2019', con=engine, if_exists='replace')
# Out:
# 0

# %%
df_2=pd.read_csv('green_tripdata_2019-10.csv.gz', nrows=100)

# %%
df_2
# Out:
#     VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0          2  2019-10-01 00:26:02   2019-10-01 00:39:58                  N
# 1          1  2019-10-01 00:18:11   2019-10-01 00:22:38                  N
# 2          1  2019-10-01 00:09:31   2019-10-01 00:24:47                  N
# 3          1  2019-10-01 00:37:40   2019-10-01 00:41:49                  N
# 4          2  2019-10-01 00:08:13   2019-10-01 00:17:56                  N
# ..       ...                  ...                   ...                ...
# 95         2  2019-10-01 00:02:53   2019-10-01 00:14:32                  N
# 96         2  2019-10-01 00:18:45   2019-10-01 00:29:23                  N
# 97         2  2019-10-01 00:41:32   2019-10-01 00:52:51                  N
# 98         2  2019-10-01 00:36:54   2019-10-01 00:54:20                  N
# 99         2  2019-10-01 00:21:27   2019-10-01 00:26:59                  N
#
# ...

# %%
from time import time

# %%
# %time df.to_sql(name='taxi_trips_10_2019', con=engine, if_exists='append')
# Out:
# CPU times: total: 5.16 s
# Wall time: 9.79 s
# 386

# %%
while True:
    t_start = time()

    df = next (df_iter)
    
    df.lpep_pickup_datetime = pd.to_datetime (df.lpep_pickup_datetime)
    df.lpep_dropoff_datetime = pd.to_datetime (df.lpep_dropoff_datetime)

    df.to_sql(name='taxi_trips_10_2019', con=engine, if_exists='append')

    t_end = time()

    print ('inserted another chunk..., took %.3f second' % (t_end - t_start))
# Out:
# inserted another chunk..., took 12.669 second
# inserted another chunk..., took 12.856 second
# C:\Users\ДаниилСавельев\AppData\Local\Temp\ipykernel_1548\996431026.py:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next (df_iter)
# inserted another chunk..., took 11.718 second
# inserted another chunk..., took 9.394 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[12], line 4
#       1 while True:
#       2     t_start = time()
# ----> 4     df = next (df_iter)
#       6     df.lpep_pickup_datetime = pd.to_datetime (df.lpep_pickup_datetime)
#       7     df.lpep_dropoff_datetime = pd.to_datetime (df.lpep_dropoff_datetime)
#
# File C:\Data Engineering\software\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1843, in TextFileReader.__next__(self)
#    1841 def __next__(self) -> DataFrame:
# ...
